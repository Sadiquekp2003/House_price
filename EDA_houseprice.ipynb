# %%
import pandas as pd
df=pd.read_csv("/content/bengaluru_house_prices.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# # **UNDERSTAND THE DATA**

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.sample()
# Out:
#             area_type   availability     location   size  society total_sqft  \
# 10644  Built-up  Area  Ready To Move  Kammasandra  2 BHK  Vicony        1415
#
#        bath  balcony  price
# 10644   2.0      2.0   60.0

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.describe(include='object')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
#
#        total_sqft
# count       13320
# unique       2117
# top          1200
# freq          843

# %%
df.describe(include=['object',"category"])
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
#
#        total_sqft
# count       13320
# unique       2117
# top          1200
# freq          843

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# count       13320  13247.000000  12711.000000  13320.000000
# unique       2117           NaN           NaN           NaN
# top          1200           NaN           NaN           NaN
# freq          843           NaN           NaN           NaN
# mean          NaN      2.692610      1.584376    112.565627
# std           NaN      1.341458      0.817263    148.971674
# min           NaN      1.000000      0.000000      8.000000
# 25%           NaN      2.000000      1.000000     50.000000
# 50%           NaN      2.000000      2.000000     72.000000
# 75%           NaN      3.000000      2.000000    120.000000
# max           NaN     40.000000      3.000000   3600.000000

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df["balcony"].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %% [markdown]
# # **DATA CLEANING**

# %%
df1=df.copy()

# %%
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df1.drop(columns=['society'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
# use mode to fill because it is an object datatype and null value is 1
df1["location"].mode()
# Out:
# 0    Whitefield
# Name: location, dtype: object

# %%
df1["location"].fillna(df1["location"].mode()[0],inplace=True)
# Out:
# <ipython-input-23-51260ed41cc1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["location"].fillna(df1["location"].mode()[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df1["size"].fillna(df1["size"].mode()[0],inplace=True)
# Out:
# <ipython-input-25-de0489551ef7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["size"].fillna(df1["size"].mode()[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df1["bath"].median()
# Out:
# 2.0

# %%
#
df1["bath"].fillna(df1["bath"].median(),inplace=True)
# Out:
# <ipython-input-28-8d2fe3b80282>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["bath"].fillna(df1["bath"].median(),inplace=True)

# %%
df1["balcony"].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
print(df.shape)
print(df1.shape)
# Out:
# (13320, 9)
# (12711, 8)

# %%
df1.duplicated().sum()
# Out:
# 564

# %%
df1.drop_duplicates(inplace=True)

# %%
print(df.shape)
print(df1.shape)
# Out:
# (13320, 9)
# (12147, 8)

# %%
df1["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df1["total_sqft"]=df1["total_sqft"].str.extract(r'(\d+\.?\d*)')

# %%
df1['total_sqft']=df1['total_sqft'].astype(float)

# %%
df1["size"]=df1["size"].str.extract(r'(\d+\.?\d*)')

# %%
df1['size']=df1['size'].astype(int)

# %%
df1
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 1                Plot  Area  Ready To Move          Chikka Tirupathi     4
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# ...                     ...            ...                       ...   ...
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13315        Built-up  Area  Ready To Move                Whitefield     5
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar     4
#
#        total_sqft  bath  balcony   price
# 0          1056.0   2.0      1.0   39.07
# 1          2600.0   5.0      3.0  120.00
# 2          1440.0   2.0      3.0   62.00
# 3          1521.0   3.0      1.0   95.00
# 4          1200.0   2.0      1.0   51.00
# ...           ...   ...      ...     ...
# 13312      1262.0   2.0      2.0   47.00
# 13314      1715.0   3.0      3.0  112.00
# 13315      3453.0   4.0      0.0  231.00
# 13317      1141.0   2.0      1.0   60.00
# 13318      4689.0   4.0      1.0  488.00
#
# [12147 rows x 8 columns]

# %%
df1["size"].unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  7,  5, 11,  9, 27, 43, 14, 12, 10, 13])

# %%
df1['bath']=df1['bath'].astype(int)
df1['balcony']=df1['balcony'].astype(int)

# %%
df1.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# total_sqft      float64
# bath              int64
# balcony           int64
# price           float64
# dtype: object

# %%
df1.describe()
# Out:
#                size    total_sqft          bath       balcony         price
# count  12147.000000  12147.000000  12147.000000  12147.000000  12147.000000
# mean       2.750720   1516.049702      2.632667      1.582531    107.786470
# std        1.222126   1184.279197      1.241833      0.823359    134.192872
# min        1.000000      1.000000      1.000000      0.000000      8.000000
# 25%        2.000000   1095.000000      2.000000      1.000000     50.000000
# 50%        3.000000   1263.000000      2.000000      2.000000     70.000000
# 75%        3.000000   1650.000000      3.000000      2.000000    115.000000
# max       43.000000  52272.000000     40.000000      3.000000   2912.000000

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set plot style
sns.set_style("whitegrid")

# Distribution plot for numeric columns
fig, axes = plt.subplots(2,2,figsize=(14,10))

# price Distribution
sns.histplot(df1["price"],color="blue",ax=axes[0,0])
axes[0,0].set_title("Price Distribution")

# Total sqft distribution
sns.histplot(df1["total_sqft"],color="orange",ax=axes[0,1])
axes[0,1].set_title("Total sqft Distribution")

# Bath distribution
sns.histplot(df1["bath"],color="green",ax=axes[1,0])
axes[1,0].set_title("Bath Distribution")

# Balcony distribution
sns.histplot(df1["balcony"],color="red",ax=axes[1,1])
axes[1,1].set_title("Balcony Distribution")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set the plot size for all plots
plt.figure(figsize=(16,12))

# Barplot: Average price by Area_type
plt.subplot(2,2,1)
sns.barplot(x="area_type",y="price",data=df1,palette="Set2")
plt.title("Average price by Area_type")
plt.xlabel("Area_type")
plt.ylabel("Average Price")

# Barplot: Average Total Sqft by Area_type
plt.subplot(2,2,2)
sns.barplot(x="area_type",y="total_sqft",data=df1,palette="Set2")
plt.title("Average Total Sqft by Area_type")
plt.xlabel("Area_type")
plt.ylabel("Average Total Sqft")

# Barplot: Average Bath by Area_type
plt.subplot(2,2,3)
sns.barplot(x="area_type",y="bath",data=df1,palette="Set2")
plt.title("Average Bath by Area_type")
plt.xlabel("Area_type")
plt.ylabel("Average Number of Bathrooms")

#Barplot: Average Balcony by Area_type
plt.subplot(2,2,4)
sns.barplot(x="area_type",y="balcony",data=df1,palette="Set2")
plt.title("Average Balcony by Area_type")
plt.xlabel("Area_type")
plt.ylabel("Average Number of Balconies")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-2c47b86658e4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="price",data=df1,palette="Set2")
# <ipython-input-48-2c47b86658e4>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="total_sqft",data=df1,palette="Set2")
# <ipython-input-48-2c47b86658e4>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="bath",data=df1,palette="Set2")
# <ipython-input-48-2c47b86658e4>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="balcony",data=df1,palette="Set2")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set the plot size for all plots
plt.figure(figsize=(16,10))

#scatterplot : Price vs Total Sqft
plt.subplot(2,2,1)
sns.scatterplot(x="total_sqft",y="price",data=df1,hue="area_type",palette="coolwarm",alpha=0.6)
plt.title("Price vs Total Sqft")
plt.xlabel("Total Sqft")
plt.ylabel("Price")

# Scatter plot:Price vs bath
plt.subplot(2,2,2)
sns.scatterplot(x="bath",y="price",data=df1,hue="area_type",palette="Set2",alpha=0.6)
plt.title("Price vs Bath")
plt.xlabel("Number of Bathrooms")
plt.ylabel("Price")

# Scatter plot:Price vs Balcony
plt.subplot(2,2,3)
sns.scatterplot(x="balcony",y="price",data=df1,hue="area_type",palette="Set2",alpha=0.6)
plt.title("Price vs Balcony")
plt.xlabel("Number of Balconies")
plt.ylabel("Price")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x="area_type",y="price",data=df1,palette="Set2")
plt.title("Price vs Area_type")
plt.xlabel("Area_type")
plt.ylabel("Price")

plt.show()
# Out:
# <ipython-input-50-7d6c72e74243>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y="price",data=df1,palette="Set2")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="area_type",data=df1,palette="Set1")
plt.title("Count of properties by  Area_type")
plt.xlabel("Area_type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

#location is likely to have many unique values,so we can limit the categories shown
plt.figure(figsize=(12,6))
top_locations=df1['location'].value_counts().nlargest(10)
sns.countplot(x="location",data=df1[df1["location"].isin(top_locations.index)],palette="Set2")
plt.title("Count of properties by Location")
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-51-fe56788c4d0b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="area_type",data=df1,palette="Set1")
# <ipython-input-51-fe56788c4d0b>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="location",data=df1[df1["location"].isin(top_locations.index)],palette="Set2")

# %%
# Pairplot to see relationships between numeric columns
sns.pairplot(df1[['price', 'total_sqft', 'bath', 'balcony']])
plt.show()

# %%
# Select only numerical columns
numerical_columns = df1.select_dtypes(include=['number'])

# %%
# calculate the correlation for numerical data
correlation_matrix = numerical_columns.corr()

#plot heatmap for correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12147 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12147 non-null  object
#  1   availability  12147 non-null  object
#  2   location      12147 non-null  object
#  3   size          12147 non-null  int64
#  4   total_sqft    12147 non-null  float64
#  5   bath          12147 non-null  int64
#  6   balcony       12147 non-null  int64
#  7   price         12147 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 854.1+ KB

# %% [markdown]
# # **OUTLIER DETECTION**

# %%
df2=df1.copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12147 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12147 non-null  object
#  1   availability  12147 non-null  object
#  2   location      12147 non-null  object
#  3   size          12147 non-null  int64
#  4   total_sqft    12147 non-null  float64
#  5   bath          12147 non-null  int64
#  6   balcony       12147 non-null  int64
#  7   price         12147 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 854.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the plot size for all plots
plt.figure(figsize=(16, 12))

# Create a subplot grid for 4 plots (2 rows, 2 columns)
plt.subplot(2, 2, 1)
sns.boxplot(x='area_type', y='price', data=df2, palette="Set2")
plt.title('Price Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Price')

plt.subplot(2, 2, 2)
sns.boxplot(x='area_type', y='total_sqft', data=df2, palette="Set2")
plt.title('Total Sqft Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Total Sqft')

plt.subplot(2, 2, 3)
sns.boxplot(x='area_type', y='bath', data=df2, palette="Set2")
plt.title('Bath Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Bathrooms')

plt.subplot(2, 2, 4)
sns.boxplot(x='area_type', y='balcony', data=df2, palette="Set2")
plt.title('Balcony Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Balconies')

# Adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-57-33e1f5c742d7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='price', data=df2, palette="Set2")
# <ipython-input-57-33e1f5c742d7>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='total_sqft', data=df2, palette="Set2")
# <ipython-input-57-33e1f5c742d7>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='bath', data=df2, palette="Set2")
# <ipython-input-57-33e1f5c742d7>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='balcony', data=df2, palette="Set2")

# %%
# Define a function to calculate IQR outliers
def detect_iqr_outliers(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return (column < lower_bound) | (column > upper_bound)


# Select only numerical columns
#numerical_cols = df2.select_dtypes(include=['number']).columns



# Apply the function to numerical columns
outliers_iqr = df2[[ 'size', 'total_sqft', 'bath',
       'balcony', 'price']].apply(detect_iqr_outliers)

# View outliers
print("Outliers detected using IQR:")
print(outliers_iqr.sum())  # Count of outliers per column
# Out:
# Outliers detected using IQR:
# size           682
# total_sqft    1051
# bath           831
# balcony          0
# price         1150
# dtype: int64

# %%
# Filter out the rows with any outliers
df2 = df2[~(outliers_iqr.any(axis=1))]
print("Data after removing outliers (IQR):")
print(df2)
# Out:
# Data after removing outliers (IQR):
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
#        total_sqft  bath  balcony   price
# 0          1056.0     2        1   39.07
# 2          1440.0     2        3   62.00
# 3          1521.0     3        1   95.00
# 4          1200.0     2        1   51.00
# 5          1170.0     2        1   38.00
# ...           ...   ...      ...     ...
# 13308      1527.0     3        1  142.00
# 13310      1050.0     2        2   52.71
# 13312      1262.0     2        2   47.00
# 13314      1715.0     3        3  112.00
# 13317      1141.0     2        1   60.00
#
# [10211 rows x 8 columns]

# %%
import numpy as np
from scipy.stats import zscore


# Compute Z-scores
z_scores = df2[[ 'size', 'total_sqft', 'bath',
       'balcony']].apply(zscore)

# Define threshold
threshold = 3

# Identify outliers
outliers_z = (z_scores.abs() > threshold)

# View outliers
print("Outliers detected using Z-Score:")
print(outliers_z.sum())  # Count of outliers per column
# Out:
# Outliers detected using Z-Score:
# size           0
# total_sqft    83
# bath           0
# balcony        0
# dtype: int64

# %%
print(df.shape)
print(df1.shape)
print(df2.shape)
# Out:
# (13320, 9)
# (12147, 8)
# (10211, 8)

# %% [markdown]
# # **FEATURE ENGINEERING**

# %%
df3 = df2.copy()
df3
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
#        total_sqft  bath  balcony   price
# 0          1056.0     2        1   39.07
# 2          1440.0     2        3   62.00
# 3          1521.0     3        1   95.00
# 4          1200.0     2        1   51.00
# 5          1170.0     2        1   38.00
# ...           ...   ...      ...     ...
# 13308      1527.0     3        1  142.00
# 13310      1050.0     2        2   52.71
# 13312      1262.0     2        2   47.00
# 13314      1715.0     3        3  112.00
# 13317      1141.0     2        1   60.00
#
# [10211 rows x 8 columns]

# %%
df3['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-Feb', '18-Nov', '18-May', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '18-Apr',
#        '20-Aug', '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr',
#        '18-Jun', '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul',
#        '18-Jul', '21-Jun', '19-Aug', '18-Sep', '17-Jun', '18-Oct',
#        '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar', '19-Jun',
#        '22-Jun', '17-May', '19-Jul', '21-Feb', '19-May', '20-Oct',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Nov', '17-Apr',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '20-Jun', '21-Sep', '21-Aug', '22-May', '14-Nov',
#        '19-Nov', '16-Jul', '15-Jun', '20-May', '20-Nov', '20-Jul',
#        '16-Sep', '20-Feb', '15-Dec', '16-Oct', '22-Nov', '15-Aug',
#        '17-Jan', '16-Nov', '20-Apr', '16-Jan', '17-Feb', '14-Jul'],
#       dtype=object)

# %%
df3['availability_status'] = np.where(df3['availability'] == 'Ready To Move', 'Immediatly available', 'Available Later')
df3.drop(columns=['availability'], inplace=True)

# %%
df3['availability_status'].value_counts()
# Out:
# availability_status
# Immediatly available    7960
# Available Later         2251
# Name: count, dtype: int64

# %% [markdown]
# # **FEATURE TRANSFORMATION**

# %%
skewness = df3[['size', 'total_sqft', 'bath', 'balcony', 'price']].skew()
print(skewness)
# Out:
# size          0.129832
# total_sqft    0.407196
# bath          0.578358
# balcony       0.064279
# price         1.208694
# dtype: float64

# %%
skewness = df1[['size', 'total_sqft', 'bath', 'balcony', 'price']].skew()
print(skewness)
# Out:
# size           5.276400
# total_sqft    17.245114
# bath           4.573851
# balcony        0.009607
# price          7.763519
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['size', 'total_sqft', 'bath', 'balcony', 'price']:
    sns.histplot(df3[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# Log transformation for 'price'
df3['price_log'] = np.log1p(df3['price'])  # log1p handles zero and large values safely

# Square root transformation for 'price'
df3['price_sqrt'] = np.sqrt(df3['price'])

# Display the results
print(df3[['price', 'price_log', 'price_sqrt']])
# Out:
#         price  price_log  price_sqrt
# 0       39.07   3.690628    6.250600
# 2       62.00   4.143135    7.874008
# 3       95.00   4.564348    9.746794
# 4       51.00   3.951244    7.141428
# 5       38.00   3.663562    6.164414
# ...       ...        ...         ...
# 13308  142.00   4.962845   11.916375
# 13310   52.71   3.983599    7.260165
# 13312   47.00   3.871201    6.855655
# 13314  112.00   4.727388   10.583005
# 13317   60.00   4.110874    7.745967
#
# [10211 rows x 3 columns]

# %%
skewness = df3[['price','price_log', 'price_sqrt']].skew()
print(skewness)
# Out:
# price         1.208694
# price_log    -0.071609
# price_sqrt    0.607233
# dtype: float64

# %%
df3.drop(columns=['price_sqrt','price'], inplace=True)

# %% [markdown]
# # **Encoding**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10211 entries, 0 to 13317
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   area_type            10211 non-null  object
#  1   location             10211 non-null  object
#  2   size                 10211 non-null  int64
#  3   total_sqft           10211 non-null  float64
#  4   bath                 10211 non-null  int64
#  5   balcony              10211 non-null  int64
#  6   availability_status  10211 non-null  object
#  7   price_log            10211 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 718.0+ KB

# %%
df3.nunique()
# Out:
# area_type                 4
# location               1094
# size                      4
# total_sqft             1391
# bath                      4
# balcony                   4
# availability_status       2
# price_log              1649
# dtype: int64

# %%
df3['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Uttarahalli', 'Lingadheeranahalli',
#        ..., 'Sarvobhogam Nagar',
#        '12th cross srinivas nagar banshankari 3rd stage', 'Abshot Layout'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df3['location'] = le.fit_transform(df3['location'])

# %%
df3['location'].dtype
# Out:
# dtype('int64')

# %%
df3['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Built-up  Area', 'Plot  Area',
#        'Carpet  Area'], dtype=object)

# %%
df3['area_type']=df3['area_type'].map({'Carpet  Area': 0, 'Plot  Area': 1,'Built-up  Area':2,'Super built-up  Area':3})
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  \
# 0              3       349     2      1056.0     2        1
# 2              2       991     3      1440.0     2        3
# 3              3       642     3      1521.0     3        1
# 4              3       608     2      1200.0     2        1
# 5              3      1052     2      1170.0     2        1
# ...          ...       ...   ...         ...   ...      ...
# 13308          2       175     3      1527.0     3        1
# 13310          3       807     2      1050.0     2        2
# 13312          3       193     2      1262.0     2        2
# 13314          3       396     3      1715.0     3        3
# 13317          2       814     2      1141.0     2        1
#
#         availability_status  price_log
# 0           Available Later   3.690628
# 2      Immediatly available   4.143135
# 3      Immediatly available   4.564348
# 4      Immediatly available   3.951244
# 5      Immediatly available   3.663562
# ...                     ...        ...
# 13308  Immediatly available   4.962845
# 13310  Immediatly available   3.983599
# 13312  Immediatly available   3.871201
# 13314  Immediatly available   4.727388
# 13317  Immediatly available   4.110874
#
# [10211 rows x 8 columns]

# %%
df3['availability_status'].unique()
# Out:
# array(['Available Later', 'Immediatly available'], dtype=object)

# %%
one_hot_encoded = pd.get_dummies(df3['availability_status'], prefix='onehot', dtype=int)

# %%
df3 = pd.concat([df3, one_hot_encoded], axis=1)
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  \
# 0              3       349     2      1056.0     2        1
# 2              2       991     3      1440.0     2        3
# 3              3       642     3      1521.0     3        1
# 4              3       608     2      1200.0     2        1
# 5              3      1052     2      1170.0     2        1
# ...          ...       ...   ...         ...   ...      ...
# 13308          2       175     3      1527.0     3        1
# 13310          3       807     2      1050.0     2        2
# 13312          3       193     2      1262.0     2        2
# 13314          3       396     3      1715.0     3        3
# 13317          2       814     2      1141.0     2        1
#
#         availability_status  price_log  onehot_Available Later  \
# 0           Available Later   3.690628                       1
# 2      Immediatly available   4.143135                       0
# 3      Immediatly available   4.564348                       0
# 4      Immediatly available   3.951244                       0
# 5      Immediatly available   3.663562                       0
# ...                     ...        ...                     ...
# 13308  Immediatly available   4.962845                       0
# 13310  Immediatly available   3.983599                       0
# 13312  Immediatly available   3.871201                       0
# 13314  Immediatly available   4.727388                       0
# 13317  Immediatly available   4.110874                       0
#
#        onehot_Immediatly available
# 0                                0
# 2                                1
# 3                                1
# 4                                1
# 5                                1
# ...                            ...
# 13308                            1
# 13310                            1
# 13312                            1
# 13314                            1
# 13317                            1
#
# [10211 rows x 10 columns]

# %%
df3.drop(columns=['availability_status'], inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.heatmap(df3.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # **SCALING**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10211 entries, 0 to 13317
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   area_type                    10211 non-null  int64
#  1   location                     10211 non-null  int64
#  2   size                         10211 non-null  int64
#  3   total_sqft                   10211 non-null  float64
#  4   bath                         10211 non-null  int64
#  5   balcony                      10211 non-null  int64
#  6   price_log                    10211 non-null  float64
#  7   onehot_Available Later       10211 non-null  int64
#  8   onehot_Immediatly available  10211 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 797.7 KB

# %%
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  price_log  \
# 0              3       349     2      1056.0     2        1   3.690628
# 2              2       991     3      1440.0     2        3   4.143135
# 3              3       642     3      1521.0     3        1   4.564348
# 4              3       608     2      1200.0     2        1   3.951244
# 5              3      1052     2      1170.0     2        1   3.663562
# ...          ...       ...   ...         ...   ...      ...        ...
# 13308          2       175     3      1527.0     3        1   4.962845
# 13310          3       807     2      1050.0     2        2   3.983599
# 13312          3       193     2      1262.0     2        2   3.871201
# 13314          3       396     3      1715.0     3        3   4.727388
# 13317          2       814     2      1141.0     2        1   4.110874
#
#        onehot_Available Later  onehot_Immediatly available
# 0                           1                            0
# 2                           0                            1
# 3                           0                            1
# 4                           0                            1
# 5                           0                            1
# ...                       ...                          ...
# 13308                       0                            1
# 13310                       0                            1
# 13312                       0                            1
# 13314                       0                            1
# 13317                       0                            1
#
# [10211 rows x 9 columns]

# %%
df3.columns
# Out:
# Index(['area_type', 'location', 'size', 'total_sqft', 'bath', 'balcony',
#        'price_log', 'onehot_Available Later', 'onehot_Immediatly available'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

MinMaxScaler=MinMaxScaler()

df_minmax_scaled=MinMaxScaler.fit_transform(df3)

# %%
df_minmax_scaled
# Out:
# array([[1.        , 0.31930467, 0.33333333, ..., 0.47269148, 1.        ,
#         0.        ],
#        [0.66666667, 0.90667887, 0.66666667, ..., 0.61591876, 0.        ,
#         1.        ],
#        [1.        , 0.5873742 , 0.66666667, ..., 0.74924109, 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.17657823, 0.33333333, ..., 0.5298464 , 0.        ,
#         1.        ],
#        [1.        , 0.36230558, 0.66666667, ..., 0.80084634, 0.        ,
#         1.        ],
#        [0.66666667, 0.74473925, 0.33333333, ..., 0.60570757, 0.        ,
#         1.        ]])

# %%
df_minmax_scaled=pd.DataFrame(df_minmax_scaled,columns=df3.columns)
df_minmax_scaled
# Out:
#        area_type  location      size  total_sqft      bath   balcony  \
# 0       1.000000  0.319305  0.333333    0.353902  0.333333  0.333333
# 1       0.666667  0.906679  0.666667    0.528131  0.333333  1.000000
# 2       1.000000  0.587374  0.666667    0.564882  0.666667  0.333333
# 3       1.000000  0.556267  0.333333    0.419238  0.333333  0.333333
# 4       1.000000  0.962489  0.333333    0.405626  0.333333  0.333333
# ...          ...       ...       ...         ...       ...       ...
# 10206   0.666667  0.160110  0.666667    0.567604  0.666667  0.333333
# 10207   1.000000  0.738335  0.333333    0.351180  0.333333  0.666667
# 10208   1.000000  0.176578  0.333333    0.447368  0.333333  0.666667
# 10209   1.000000  0.362306  0.666667    0.652904  0.666667  1.000000
# 10210   0.666667  0.744739  0.333333    0.392468  0.333333  0.333333
#
#        price_log  onehot_Available Later  onehot_Immediatly available
# 0       0.472691                     1.0                          0.0
# 1       0.615919                     0.0                          1.0
# 2       0.749241                     0.0                          1.0
# 3       0.555181                     0.0                          1.0
# 4       0.464124                     0.0                          1.0
# ...          ...                     ...                          ...
# 10206   0.875373                     0.0                          1.0
# 10207   0.565423                     0.0                          1.0
# 10208   0.529846                     0.0                          1.0
# 10209   0.800846                     0.0                          1.0
# 10210   0.605708                     0.0                          1.0
#
# [10211 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 10))

# Original and scaled data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Original: size')

plt.subplot(5, 2, 2)
sns.histplot(df_minmax_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Original: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_minmax_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['bath'], kde=True)
plt.title('Original: bath')

plt.subplot(5, 2, 6)
sns.histplot(df_minmax_scaled['bath'], kde=True)
plt.title('Scaled: bath')

plt.subplot(5, 2, 7)
sns.histplot(df3['balcony'], kde=True)
plt.title('Original: balcony')

plt.subplot(5, 2, 8)
sns.histplot(df_minmax_scaled['balcony'], kde=True)
plt.title('Scaled: balcony')

plt.subplot(5, 2, 9)
sns.histplot(df3['price_log'], kde=True)
plt.title('Original: price_log')

plt.subplot(5, 2, 10)
sns.histplot(df_minmax_scaled['price_log'], kde=True)
plt.title('Scaled: log_price')


plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

#
standard_scaler=StandardScaler()
df_stadardized=standard_scaler.fit_transform(df3)

# %%
df_stadardized=pd.DataFrame(df_stadardized,columns=df3.columns)
df_stadardized
# Out:
#        area_type  location      size  total_sqft      bath   balcony  \
# 0       0.564389 -0.690100 -0.630447   -0.608959 -0.424650 -0.696602
# 1      -0.917858  1.396380  0.859369    0.425854 -0.424650  1.849212
# 2       0.564389  0.262141  0.859369    0.644135  1.087766 -0.696602
# 3       0.564389  0.151642 -0.630447   -0.220904 -0.424650 -0.696602
# 4       0.564389  1.594628 -0.630447   -0.301749 -0.424650 -0.696602
# ...          ...       ...       ...         ...       ...       ...
# 10206  -0.917858 -1.255595  0.859369    0.660304  1.087766 -0.696602
# 10207   0.564389  0.798386 -0.630447   -0.625128 -0.424650  0.576305
# 10208   0.564389 -1.197095 -0.630447   -0.053825 -0.424650  0.576305
# 10209   0.564389 -0.537352  0.859369    1.166931  1.087766  1.849212
# 10210  -0.917858  0.821136 -0.630447   -0.379898 -0.424650 -0.696602
#
#        price_log  onehot_Available Later  onehot_Immediatly available
# 0      -1.019556                1.880480                    -1.880480
# 1      -0.088612               -0.531779                     0.531779
# 2       0.777952               -0.531779                     0.531779
# 3      -0.483390               -0.531779                     0.531779
# 4      -1.075240               -0.531779                     0.531779
# ...          ...                     ...                          ...
# 10206   1.597781               -0.531779                     0.531779
# 10207  -0.416825               -0.531779                     0.531779
# 10208  -0.648062               -0.531779                     0.531779
# 10209   1.113374               -0.531779                     0.531779
# 10210  -0.154982               -0.531779                     0.531779
#
# [10211 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 10))

# Original and scaled data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Original: size')

plt.subplot(5, 2, 2)
sns.histplot(df_minmax_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Original: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_minmax_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')
# Out:
# Text(0.5, 1.0, 'Scaled: total_sqft')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.heatmap(df_stadardized.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
x=df_stadardized.drop(columns=['price_log'])
y=df_stadardized['price_log']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)

from sklearn.metrics import r2_score, mean_squared_error

# Training predictions
# y_train_pred = model.predict(x_train)
# r2_train = r2_score(y_train, y_train_pred)
# mse_train = mean_squared_error(y_train, y_train_pred)

# Validation predictions
y_pred = model.predict(x_test)  # Use validation set
r2_val = r2_score(y_test, y_pred)
mse_val = mean_squared_error(y_test, y_pred)

#print("R² Score (Train):", r2_train)
print("R² Score (Validation):", r2_val)
#print("MSE (Train):", mse_train)
print("MSE (Validation):", mse_val)
# Out:
# R² Score (Validation): 0.5362534662715434
# MSE (Validation): 0.45536603590780367

# %% [markdown]
# # Dimensianality Reduction

# %% [markdown]
# ## Feature extraction(PCA)

# %%
x=df_stadardized.drop(columns=['price_log'])
y=df_stadardized['price_log']

# %%
x.head()
# Out:
#    area_type  location      size  total_sqft      bath   balcony  \
# 0   0.564389 -0.690100 -0.630447   -0.608959 -0.424650 -0.696602
# 1  -0.917858  1.396380  0.859369    0.425854 -0.424650  1.849212
# 2   0.564389  0.262141  0.859369    0.644135  1.087766 -0.696602
# 3   0.564389  0.151642 -0.630447   -0.220904 -0.424650 -0.696602
# 4   0.564389  1.594628 -0.630447   -0.301749 -0.424650 -0.696602
#
#    onehot_Available Later  onehot_Immediatly available
# 0                1.880480                    -1.880480
# 1               -0.531779                     0.531779
# 2               -0.531779                     0.531779
# 3               -0.531779                     0.531779
# 4               -0.531779                     0.531779

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x)

# %%
x_pca
# Out:
# array([[-1.78762836,  2.34547864],
#        [ 1.2929327 , -0.70931382],
#        [ 1.30959606, -0.22905794],
#        ...,
#        [-0.27908892, -0.86353143],
#        [ 2.37094833, -0.22142636],
#        [-0.73659783, -1.00445575]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8168, 2)
# (2043, 2)
# (8168,)
# (2043,)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error

#validation predictions
y_pred=model.predict(x_test)
r2_val=r2_score(y_test,y_pred)
mse_val=mean_squared_error(y_test,y_pred)

print("R2 score (validation):",r2_val)
print("MSE (validation)",mse_val)
# Out:
# R2 score (validation): 0.4510008608740209
# MSE (validation) 0.5390780168008263

# %%
y_pred=model.predict(x_test)
print(y_pred)
print(y_pred.shape)
# Out:
# [ 0.39053453 -0.31759707 -0.49708729 ...  1.13316237  0.28296507
#  -0.38614728]
# (2043,)

# %%
#MAE (Mean Absolute Error)

from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print("MAE",mae)
# Out:
# MAE 0.5771487123568513

# %%
# MSE (Mean squared Error)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('MSE: ',mse)
# Out:
# MSE:  0.5390780168008263

# %%
# RMSE (Root Mean Squared Error)
rmse=np.sqrt(mse)
print("RMSE",rmse)
# Out:
# RMSE 0.7342193247258113

# %%
# R² Score (R-squared)

from sklearn.metrics import  r2_score

r2 = r2_score(y_test, y_pred)
print('R² Score: ',r2)
# Out:
# R² Score:  0.4510008608740209
